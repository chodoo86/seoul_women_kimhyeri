# %% [markdown]
# # 20 Model Evaluation
# Simple view of latest scores.

# %%
import sqlite3, pandas as pd
con = sqlite3.connect('build/ivd.db')
pd.read_sql_query('SELECT * FROM bi_scores_daily ORDER BY run_date DESC LIMIT 10', con)
