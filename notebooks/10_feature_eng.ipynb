# %% [markdown]
# # 10 Feature Engineering
# This notebook shows how the feature view is used.

# %%
import sqlite3, pandas as pd
con = sqlite3.connect('build/ivd.db')
pd.read_sql_query('SELECT * FROM feature_view LIMIT 5', con)
